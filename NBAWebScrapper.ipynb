# %% [markdown]
# ## NBA Short chart details Web scraping
# ### Benchmark

# %%
import requests
import pandas as pd

# %%
headers = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'X-NewRelic-ID': 'VQECWF5UChAHUlNTBwgBVw==',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4215.0 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://stats.nba.com/events/?flag=3&CFID=33&CFPARAMS=2019-20&PlayerID=1628369&ContextMeasure=FGA&Season=2019-20&section=player&sct=hex',
    'Accept-Language': 'en-US,en;q=0.9',
}

params = (
    ('AheadBehind', ''),
    ('ClutchTime', ''),
    ('Conference', ''),
    ('ContextFilter', ''),
    ('ContextMeasure', 'FGA'),
    ('DateFrom', ''),
    ('DateTo', ''),
    ('Division', ''),
    ('EndPeriod', '10'),
    ('EndRange', '28800'),
    ('GROUP_ID', ''),
    ('GameEventID', ''),
    ('GameID', ''),
    ('GameSegment', ''),
    ('GroupID', ''),
    ('GroupMode', ''),
    ('GroupQuantity', '5'),
    ('LastNGames', '0'),
    ('LeagueID', '00'),
    ('Location', ''),
    ('Month', '0'),
    ('OnOff', ''),
    ('OpponentTeamID', '0'),
    ('Outcome', ''),
    ('PORound', '0'),
    ('Period', '0'),
    ('PlayerID', '1628369'),
    ('PlayerID1', ''),
    ('PlayerID2', ''),
    ('PlayerID3', ''),
    ('PlayerID4', ''),
    ('PlayerID5', ''),
    ('PlayerPosition', ''),
    ('PointDiff', ''),
    ('Position', ''),
    ('RangeType', '0'),
    ('RookieYear', ''),
    ('Season', '2019-20'),
    ('SeasonSegment', ''),
    ('SeasonType', 'Regular Season'),
    ('ShotClockRange', ''),
    ('StartPeriod', '1'),
    ('StartRange', '0'),
    ('StarterBench', ''),
    ('TeamID', '0'),
    ('VsConference', ''),
    ('VsDivision', ''),
    ('VsPlayerID1', ''),
    ('VsPlayerID2', ''),
    ('VsPlayerID3', ''),
    ('VsPlayerID4', ''),
    ('VsPlayerID5', ''),
    ('VsTeamID', ''),
)

# %%
response = requests.get('https://stats.nba.com/stats/shotchartdetail', headers=headers, params=params)

jsn = response.json()
frame = pd.DataFrame(jsn['resultSets'][0]['rowSet'])
frame.columns = jsn['resultSets'][0]['headers']
print(frame.head(10))
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0  Shot Chart Detail  0021900008              7    1628369  Jayson Tatum
# 1  Shot Chart Detail  0021900008             76    1628369  Jayson Tatum
# 2  Shot Chart Detail  0021900008            100    1628369  Jayson Tatum
# 3  Shot Chart Detail  0021900008            107    1628369  Jayson Tatum
# 4  Shot Chart Detail  0021900008            122    1628369  Jayson Tatum
# 5  Shot Chart Detail  0021900008            145    1628369  Jayson Tatum
# 6  Shot Chart Detail  0021900008            148    1628369  Jayson Tatum
# 7  Shot Chart Detail  0021900008            156    1628369  Jayson Tatum
# 8  Shot Chart Detail  0021900008            162    1628369  Jayson Tatum
# 9  Shot Chart Detail  0021900008            282    1628369  Jayson Tatum
#
#       TEAM_ID       TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612738  Boston Celtics       1                 11                 38
# 1  1610612738  Boston Celtics       1                  6                  7
# 2  1610612738  Boston Celtics       1                  4                 47
# 3  1610612738  Boston Celtics       1                  4                 25
# 4  1610612738  Boston Celtics       1                  3                 23
# 5  1610612738  Boston Celtics       1                  2                 15
# 6  1610612738  Boston Celtics       1                  1                 26
# 7  1610612738  Boston Celtics       1                  0                 31
# 8  1610612738  Boston Celtics       1                  0                  2
# 9  1610612738  Boston Celtics       2                  5                  9
#
#    ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0  ...   Left Side Center(LC)        16-24 ft.            16  -124   111
# 1  ...              Center(C)  Less Than 8 ft.             1   -14     1
# 2  ...  Right Side Center(RC)          24+ ft.            25   127   226
# 3  ...              Center(C)  Less Than 8 ft.             1   -18     5
# 4  ...              Center(C)  Less Than 8 ft.             1    -3   -11
# 5  ...              Center(C)          24+ ft.            24   -59   241
# 6  ...              Center(C)          24+ ft.            27    36   268
# 7  ...              Center(C)          24+ ft.            26    47   256
# 8  ...  Right Side Center(RC)          24+ ft.            25   181   177
# 9  ...   Left Side Center(LC)        16-24 ft.            17  -123   119
#
#   SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                   1               0   20191023  PHI  BOS
# 1                   1               0   20191023  PHI  BOS
# 2                   1               0   20191023  PHI  BOS
# 3                   1               0   20191023  PHI  BOS
# 4                   1               1   20191023  PHI  BOS
# 5                   1               1   20191023  PHI  BOS
# 6                   1               0   20191023  PHI  BOS
# 7                   1               0   20191023  PHI  BOS
# 8                   1               1   20191023  PHI  BOS
# 9                   1               0   20191023  PHI  BOS
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Testing

# %%
headers = { "Accept": "application/json, text/plain, */*",
"Accept-Encoding": "gzip, deflate, br",
"Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
"Cache-Control": "no-cache",
"Connection": "keep-alive",
"Host": "stats.nba.com",
"Pragma": "no-cache",
"Referer": "https://stats.nba.com/events/?flag=3&CFID=33&CFPARAMS=2019-20&PlayerID=2544&ContextMeasure=FGA&Season=2019-20&section=player&sct=hex",
"Sec-Fetch-Dest": "empty",
"Sec-Fetch-Mode": "cors",
"Sec-Fetch-Site": "same-origin",
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
"x-nba-stats-origin": "stats",
"x-nba-stats-token": "true",
"X-NewRelic-ID": "VQECWF5UChAHUlNTBwgBVw==" }

# %%
params =(
    ('AheadBehind', ''),
    ('CFID', '33'),
    ('CFPARAMS', '2019-20'),
    ('ClutchTime', ''),
    ('Conference', ''),
    ('ContextFilter', ''),
    ('ContextMeasure', 'FGA'),
    ('DateFrom', ''),
    ('DateTo', ''),
    ('Division', ''),
    ('EndPeriod', '10'),
    ('EndRange', '28800'),
    ('GROUP_ID', ''),
    ('GameEventID', ''),
    ('GameID', ''),
    ('GameSegment', ''),
    ('GroupID', ''),
    ('GroupMode', ''),
    ('GroupQuantity', '5'),
    ('LastNGames', '0'),
    ('LeagueID', '00'),
    ('Location', ''),
    ('Month', '0'),
    ('OnOff', ''),
    ('OpponentTeamID', '0'),
    ('Outcome', ''),
    ('PORound', '0'),
    ('Period', '0'),
    ('PlayerID', '2544'),
    ('PlayerID1', ''),
    ('PlayerID2', ''),
    ('PlayerID3', ''),
    ('PlayerID4', ''),
    ('PlayerID5', ''),
    ('PlayerPosition', ''),
    ('PointDiff', ''),
    ('Position', ''),
    ('RangeType', '0'),
    ('RookieYear', ''),
    ('Season', '2019-20'),
    ('SeasonSegment', ''),
    ('SeasonType', 'Regular Season'),
    ('ShotClockRange', ''),
    ('StartPeriod', '1'),
    ('StartRange', '0'),
    ('StarterBench', ''),
    ('TeamID', '0'),
    ('VsConference', ''),
    ('VsDivision', ''),
    ('VsPlayerID1', ''),
    ('VsPlayerID2', ''),
    ('VsPlayerID3', ''),
    ('VsPlayerID4', ''),
    ('VsPlayerID5', ''),
    ('VsTeamID', ''),
)

# %%
response = requests.get('https://stats.nba.com/stats/shotchartdetail', headers=headers, params=params)

jsn = response.json()
frame = pd.DataFrame(jsn['resultSets'][0]['rowSet'])
frame.columns = jsn['resultSets'][0]['headers']
print(frame.head(10))
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0  Shot Chart Detail  0021900002              7       2544  LeBron James
# 1  Shot Chart Detail  0021900002             21       2544  LeBron James
# 2  Shot Chart Detail  0021900002             59       2544  LeBron James
# 3  Shot Chart Detail  0021900002            129       2544  LeBron James
# 4  Shot Chart Detail  0021900002            187       2544  LeBron James
# 5  Shot Chart Detail  0021900002            203       2544  LeBron James
# 6  Shot Chart Detail  0021900002            206       2544  LeBron James
# 7  Shot Chart Detail  0021900002            214       2544  LeBron James
# 8  Shot Chart Detail  0021900002            289       2544  LeBron James
# 9  Shot Chart Detail  0021900002            315       2544  LeBron James
#
#       TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612747  Los Angeles Lakers       1                 11
# 1  1610612747  Los Angeles Lakers       1                 10
# 2  1610612747  Los Angeles Lakers       1                  6
# 3  1610612747  Los Angeles Lakers       1                  3
# 4  1610612747  Los Angeles Lakers       2                 10
# 5  1610612747  Los Angeles Lakers       2                  9
# 6  1610612747  Los Angeles Lakers       2                  9
# 7  1610612747  Los Angeles Lakers       2                  8
# 8  1610612747  Los Angeles Lakers       2                  3
# 9  1610612747  Los Angeles Lakers       2                  1
#
#    SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                 47  ...              Center(C)  Less Than 8 ft.
# 1                  5  ...           Left Side(L)         8-16 ft.
# 2                 58  ...              Center(C)          24+ ft.
# 3                 51  ...              Center(C)         8-16 ft.
# 4                 48  ...  Right Side Center(RC)          24+ ft.
# 5                 33  ...              Center(C)  Less Than 8 ft.
# 6                  2  ...              Center(C)  Less Than 8 ft.
# 7                 32  ...              Center(C)  Less Than 8 ft.
# 8                 23  ...              Center(C)  Less Than 8 ft.
# 9                 33  ...   Left Side Center(LC)          24+ ft.
#
#   SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0             2    -9    23                   1               1   20191022
# 1            14  -144    41                   1               1   20191022
# 2            25   -66   251                   1               0   20191022
# 3            10     5   109                   1               0   20191022
# 4            29   220   190                   1               1   20191022
# 5             7   -77    17                   1               0   20191022
# 6             7   -16    71                   1               1   20191022
# 7             2   -13    17                   1               1   20191022
# 8             1   -11     5                   1               0   20191022
# 9            33  -188   283                   1               0   20191022
#
#    HTM  VTM
# 0  LAC  LAL
# 1  LAC  LAL
# 2  LAC  LAL
# 3  LAC  LAL
# 4  LAC  LAL
# 5  LAC  LAL
# 6  LAC  LAL
# 7  LAC  LAL
# 8  LAC  LAL
# 9  LAC  LAL
#
# [10 rows x 24 columns]

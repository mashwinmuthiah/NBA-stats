# %% [markdown]
# ## NBA Short chart details Web scraping
# ### Benchmark

# %%
import requests
import pandas as pd
import time
import pickle

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
headers = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'X-NewRelic-ID': 'VQECWF5UChAHUlNTBwgBVw==',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4215.0 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://stats.nba.com/events/?flag=3&CFID=33&CFPARAMS=2019-20&PlayerID=1628369&ContextMeasure=FGA&Season=2019-20&section=player&sct=hex',
    'Accept-Language': 'en-US,en;q=0.9',
}

params = (
    ('AheadBehind', ''),
    ('ClutchTime', ''),
    ('Conference', ''),
    ('ContextFilter', ''),
    ('ContextMeasure', 'FGA'),
    ('DateFrom', ''),
    ('DateTo', ''),
    ('Division', ''),
    ('EndPeriod', '10'),
    ('EndRange', '28800'),
    ('GROUP_ID', ''),
    ('GameEventID', ''),
    ('GameID', ''),
    ('GameSegment', ''),
    ('GroupID', ''),
    ('GroupMode', ''),
    ('GroupQuantity', '5'),
    ('LastNGames', '0'),
    ('LeagueID', '00'),
    ('Location', ''),
    ('Month', '0'),
    ('OnOff', ''),
    ('OpponentTeamID', '0'),
    ('Outcome', ''),
    ('PORound', '0'),
    ('Period', '0'),
    ('PlayerID', '1628369'),
    ('PlayerID1', ''),
    ('PlayerID2', ''),
    ('PlayerID3', ''),
    ('PlayerID4', ''),
    ('PlayerID5', ''),
    ('PlayerPosition', ''),
    ('PointDiff', ''),
    ('Position', ''),
    ('RangeType', '0'),
    ('RookieYear', ''),
    ('Season', '2019-20'),
    ('SeasonSegment', ''),
    ('SeasonType', 'Regular Season'),
    ('ShotClockRange', ''),
    ('StartPeriod', '1'),
    ('StartRange', '0'),
    ('StarterBench', ''),
    ('TeamID', '0'),
    ('VsConference', ''),
    ('VsDivision', ''),
    ('VsPlayerID1', ''),
    ('VsPlayerID2', ''),
    ('VsPlayerID3', ''),
    ('VsPlayerID4', ''),
    ('VsPlayerID5', ''),
    ('VsTeamID', ''),
)

# %%
response = requests.get('https://stats.nba.com/stats/shotchartdetail', headers=headers, params=params)

jsn = response.json()
frame = pd.DataFrame(jsn['resultSets'][0]['rowSet'])
frame.columns = jsn['resultSets'][0]['headers']
frame.head(10)
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME     TEAM_ID       TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING   EVENT_TYPE                     ACTION_TYPE       SHOT_TYPE    SHOT_ZONE_BASIC         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG GAME_DATE  HTM  VTM
# 0  Shot Chart Detail  0021900008              7    1628369  Jayson Tatum  1610612738  Boston Celtics       1                 11                 38  Missed Shot              Fadeaway Jump Shot  2PT Field Goal          Mid-Range   Left Side Center(LC)        16-24 ft.             16   -124    111                    1               0  20191023  PHI  BOS
# ...

# %% [markdown]
# ### Testing

# %%
headers = { "Accept": "application/json, text/plain, */*",
"Accept-Encoding": "gzip, deflate, br",
"Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
"Cache-Control": "no-cache",
"Connection": "keep-alive",
"Host": "stats.nba.com",
"Pragma": "no-cache",
"Referer": "https://stats.nba.com/events/?flag=3&CFID=33&CFPARAMS=2019-20&PlayerID=2544&ContextMeasure=FGA&Season=2019-20&section=player&sct=hex",
"Sec-Fetch-Dest": "empty",
"Sec-Fetch-Mode": "cors",
"Sec-Fetch-Site": "same-origin",
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
"x-nba-stats-origin": "stats",
"x-nba-stats-token": "true",
"X-NewRelic-ID": "VQECWF5UChAHUlNTBwgBVw==" }

# %%
params =(
    ('AheadBehind', ''),
    ('CFID', '33'),
    ('CFPARAMS', '2019-20'),
    ('ClutchTime', ''),
    ('Conference', ''),
    ('ContextFilter', ''),
    ('ContextMeasure', 'FGA'),
    ('DateFrom', ''),
    ('DateTo', ''),
    ('Division', ''),
    ('EndPeriod', '10'),
    ('EndRange', '28800'),
    ('GROUP_ID', ''),
    ('GameEventID', ''),
    ('GameID', ''),
    ('GameSegment', ''),
    ('GroupID', ''),
    ('GroupMode', ''),
    ('GroupQuantity', '5'),
    ('LastNGames', '0'),
    ('LeagueID', '00'),
    ('Location', ''),
    ('Month', '0'),
    ('OnOff', ''),
    ('OpponentTeamID', '0'),
    ('Outcome', ''),
    ('PORound', '0'),
    ('Period', '0'),
    ('PlayerID', '2544'),
    ('PlayerID1', ''),
    ('PlayerID2', ''),
    ('PlayerID3', ''),
    ('PlayerID4', ''),
    ('PlayerID5', ''),
    ('PlayerPosition', ''),
    ('PointDiff', ''),
    ('Position', ''),
    ('RangeType', '0'),
    ('RookieYear', ''),
    ('Season', '2019-20'),
    ('SeasonSegment', ''),
    ('SeasonType', 'Regular Season'),
    ('ShotClockRange', ''),
    ('StartPeriod', '1'),
    ('StartRange', '0'),
    ('StarterBench', ''),
    ('TeamID', '0'),
    ('VsConference', ''),
    ('VsDivision', ''),
    ('VsPlayerID1', ''),
    ('VsPlayerID2', ''),
    ('VsPlayerID3', ''),
    ('VsPlayerID4', ''),
    ('VsPlayerID5', ''),
    ('VsTeamID', ''),
)

# %%
response = requests.get('https://stats.nba.com/stats/shotchartdetail', headers=headers, params=params)

jsn = response.json()
frame = pd.DataFrame(jsn['resultSets'][0]['rowSet'])
frame.columns = jsn['resultSets'][0]['headers']
frame.head(10)
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME     TEAM_ID           TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING   EVENT_TYPE               ACTION_TYPE       SHOT_TYPE        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG GAME_DATE  HTM  VTM
# 0  Shot Chart Detail  0021900002              7       2544  LeBron James  1610612747  Los Angeles Lakers       1                 11                 47    Made Shot                Layup Shot  2PT Field Goal        Restricted Area              Center(C)  Less Than 8 ft.              2     -9     23                    1               1  20191022  LAC  LAL
# ...

# %% [markdown]
# ### Team list

# %%
url = 'https://data.nba.net/prod/v2/2019/teams.json'
df = pd.read_json(url)
df = pd.DataFrame(df.loc['vegas',:][1])

# %%
df.head()
# Out:
#    isNBAFranchise  isAllStar       city altCityName           fullName tricode      teamId nickname  urlName teamShortName confName divName
# 0            True      False    Atlanta     Atlanta      Atlanta Hawks     ATL  1610612737    Hawks    hawks       Atlanta   summer
# 1            True      False     Boston      Boston     Boston Celtics     BOS  1610612738  Celtics  celtics        Boston   summer
# 2            True      False   Brooklyn    Brooklyn      Brooklyn Nets     BKN  1610612751     Nets     nets      Brooklyn   summer
# 3            True      False  Charlotte   Charlotte  Charlotte Hornets     CHA  1610612766  Hornets  hornets     Charlotte   summer
# 4            True      False    Chicago     Chicago      Chicago Bulls     CHI  1610612741    Bulls    bulls       Chicago   summer

# %%
team_ids = list(df[df['isNBAFranchise'] == True]['teamId'])

# %%
team_ids[0:5]
# Out:
# ['1610612737', '1610612738', '1610612751', '1610612766', '1610612741']

# %%
df[df.teamId == "1610612761"]['tricode'].iloc[0]
# Out:
# 'TOR'

# %% [markdown]
# ### Team Roster

# %%
def get_roster(team_id):
    
    header = {
        "Accept": "application/json, text/plain, */*",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
        "Cache-Control": "no-cache",
        "Connection": "keep-alive",
        "Host": "stats.nba.com",
        "Pragma": "no-cache",
        "Referer": "https://stats.nba.com/team/{}/".format(team_id),
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
        "x-nba-stats-origin": "stats",
        "x-nba-stats-token": "true",
        "X-NewRelic-ID": "VQECWF5UChAHUlNTBwgBVw=="
            }

    params = (
        ("LeagueID", "00"),
        ("Season", "2019-20"),
        ("TeamID", "{}".format(team_id)),
        ("resource","commonteamroster") )
    
    response = requests.get('https://stats.nba.com/stats/commonteamroster', headers=header, params=params)

    jsn = response.json()
    frame = pd.DataFrame(jsn['resultSets'][0]['rowSet'])
    frame.columns = jsn['resultSets'][0]['headers']
    return frame

# %%
roster_byteam = {}
for i in team_ids:
    roster = get_roster(i)
    team_name = df[df.teamId == "{}".format(i)].teamShortName.iloc[0]
    print("Roster scrapped succesfully for {}".format(team_name))
    roster_byteam[team_name] = roster
    time.sleep(1)
# Out:
# Roster scrapped succesfully for Atlanta
# Roster scrapped succesfully for Boston
# Roster scrapped succesfully for Brooklyn
# Roster scrapped succesfully for Charlotte
# Roster scrapped succesfully for Chicago
# Roster scrapped succesfully for Cleveland
# Roster scrapped succesfully for Dallas
# Roster scrapped succesfully for Denver
# Roster scrapped succesfully for Detroit
# Roster scrapped succesfully for Golden State
# Roster scrapped succesfully for Houston
# Roster scrapped succesfully for Indiana
# Roster scrapped succesfully for LA Clippers
# Roster scrapped succesfully for L.A. Lakers
# Roster scrapped succesfully for Memphis
# Roster scrapped succesfully for Miami
# Roster scrapped succesfully for Milwaukee
# Roster scrapped succesfully for Minnesota
# Roster scrapped succesfully for New Orleans
# Roster scrapped succesfully for New York
# Roster scrapped succesfully for Oklahoma City
# Roster scrapped succesfully for Orlando
# Roster scrapped succesfully for Philadelphia
# ...

# %%
filename = 'roster'
outfile = open(filename,'wb')
pickle.dump(roster_byteam,outfile)
outfile.close()

# %%
filename = 'roster'
infile = open(filename,'rb')
new_dict = pickle.load(infile)

# %%
new_dict['Boston'].head()
# Out:
#        TeamID SEASON LeagueID          PLAYER     PLAYER_SLUG NUM POSITION  \
# 0  1610612738   2019       00    Jayson Tatum    jayson_tatum   0      F-G
# 1  1610612738   2019       00  Carsen Edwards  carsen_edwards   4        G
# 2  1610612738   2019       00    Jaylen Brown    jaylen_brown   7      G-F
# 3  1610612738   2019       00    Kemba Walker    kemba_walker   8        G
# 4  1610612738   2019       00  Brad Wanamaker  brad_wanamaker   9        G
#
#   HEIGHT WEIGHT    BIRTH_DATE   AGE EXP       SCHOOL  PLAYER_ID
# 0    6-8    210  MAR 03, 1998  22.0   2         Duke    1628369
# 1   5-11    200  MAR 12, 1998  22.0   R       Purdue    1629035
# 2    6-6    223  OCT 24, 1996  23.0   3   California    1627759
# 3    6-0    184  MAY 08, 1990  30.0   8  Connecticut     202689
# 4    6-3    210  JUL 25, 1989  30.0   1   Pittsburgh     202954

# %% [markdown]
# ## Top 50 league leaders

# %%
header = {
    "Accept": "application/json, text/plain, */*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Host": "stats.nba.com",
    "Pragma": "no-cache",
    "Referer": "https://stats.nba.com/leaders/?Season=2019-20&SeasonType=Regular%20Season&PerMode=Totals",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
    "x-nba-stats-origin": "stats",
    "x-nba-stats-token": "true",
}

# %%
params = (
    ("ActiveFlag", ""),
    ("LeagueID", "00"),
    ("PerMode", "Totals"),
    ("Scope", "S"),
    ("Season", "2019-20"),
    ("SeasonType", "Regular Season"),
    ("StatCategory", "PTS"),
    ("resource", "leagueleaders"))

# %%
url = "https://stats.nba.com/stats/leagueLeaders"

# %%
response = requests.get(url, headers=header, params=params)
jsn = response.json()
frame = pd.DataFrame(jsn['resultSet']['rowSet'])
frame.columns = jsn['resultSet']['headers']
frame
# Out:
#      PLAYER_ID  RANK                 PLAYER TEAM  GP   MIN  FGM   FGA  FG_PCT  \
# 0       201935     1           James Harden  HOU  66  2421  650  1477   0.440
# 1       203081     2         Damian Lillard  POR  64  2389  594  1295   0.459
# 2       203507     3  Giannis Antetokounmpo  MIL  62  1907  684  1235   0.554
# 3      1626164     4           Devin Booker  PHX  68  2439  605  1239   0.488
# 4      1629027     5             Trae Young  ATL  60  2120  546  1249   0.437
# ..         ...   ...                    ...  ...  ..   ...  ...   ...     ...
# 522    1629734   520         Kyle Alexander  MIA   1     1    0     1   0.000
# 523    1629677   520           Luka Samanic  SAS   1    12    0     4   0.000
# 524    1629716   520         Marques Bolden  CLE   1     3    0     0   0.000
# 525    1629742   520           Stanton Kidd  UTA   4    15    0     3   0.000
# 526    1629739   520         William Howard  HOU   2    13    0     4   0.000
#
# ...

# %%
Player_ids = frame[:50].PLAYER_ID
for i in Player_ids:
    print(i)
# Out:
# 201935
# 203081
# 203507
# 1626164
# 1629027
# 203078
# 1629029
# 2544
# 1628378
# 203076
# 201566
# 203897
# 203468
# 1628369
# 202695
# 201942
# 1627742
# 203999
# 202699
# 1627783
# 1629012
# 1627741
# 203933
# 203915
# 1628983
# 203114
# 202711
# 203944
# 203095
# 101108
# 203471
# 202696
# 203952
# 1626149
# 201950
# 101150
# 1629630
# 203954
# 1627759
# 202710
# 1627734
# 1628984
# 201568
# 1628389
# 1628415
# 1626179
# 204001
# 202689
# 200768
# 203501

# %%
shortchart = {}
Player_ids = frame[:50].PLAYER_ID
for i in Player_ids:
    headers = { "Accept": "application/json, text/plain, */*",
                "Accept-Encoding": "gzip, deflate, br",
                "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
                "Cache-Control": "no-cache",
                "Connection": "keep-alive",
                "Host": "stats.nba.com",
                "Pragma": "no-cache",
                "Referer": "https://stats.nba.com/events/?flag=3&CFID=33&CFPARAMS=2019-20&PlayerID={}&ContextMeasure=FGA&Season=2019-20&section=player&sct=hex".format(i),
                "Sec-Fetch-Dest": "empty",
                "Sec-Fetch-Mode": "cors",
                "Sec-Fetch-Site": "same-origin",
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
                "x-nba-stats-origin": "stats",
                "x-nba-stats-token": "true",
                "X-NewRelic-ID": "VQECWF5UChAHUlNTBwgBVw==" }
    params =(
    ('AheadBehind', ''),
    ('CFID', '33'),
    ('CFPARAMS', '2019-20'),
    ('ClutchTime', ''),
    ('Conference', ''),
    ('ContextFilter', ''),
    ('ContextMeasure', 'FGA'),
    ('DateFrom', ''),
    ('DateTo', ''),
    ('Division', ''),
    ('EndPeriod', '10'),
    ('EndRange', '28800'),
    ('GROUP_ID', ''),
    ('GameEventID', ''),
    ('GameID', ''),
    ('GameSegment', ''),
    ('GroupID', ''),
    ('GroupMode', ''),
    ('GroupQuantity', '5'),
    ('LastNGames', '0'),
    ('LeagueID', '00'),
    ('Location', ''),
    ('Month', '0'),
    ('OnOff', ''),
    ('OpponentTeamID', '0'),
    ('Outcome', ''),
    ('PORound', '0'),
    ('Period', '0'),
    ('PlayerID', '{}'.format(i)),
    ('PlayerID1', ''),
    ('PlayerID2', ''),
    ('PlayerID3', ''),
    ('PlayerID4', ''),
    ('PlayerID5', ''),
    ('PlayerPosition', ''),
    ('PointDiff', ''),
    ('Position', ''),
    ('RangeType', '0'),
    ('RookieYear', ''),
    ('Season', '2019-20'),
    ('SeasonSegment', ''),
    ('SeasonType', 'Regular Season'),
    ('ShotClockRange', ''),
    ('StartPeriod', '1'),
    ('StartRange', '0'),
    ('StarterBench', ''),
    ('TeamID', '0'),
    ('VsConference', ''),
    ('VsDivision', ''),
    ('VsPlayerID1', ''),
    ('VsPlayerID2', ''),
    ('VsPlayerID3', ''),
    ('VsPlayerID4', ''),
    ('VsPlayerID5', ''),
    ('VsTeamID', ''),
    )
    
    response = requests.get('https://stats.nba.com/stats/shotchartdetail', headers=headers, params=params)

    jsn = response.json()
    frame = pd.DataFrame(jsn['resultSets'][0]['rowSet'])
    frame.columns = jsn['resultSets'][0]['headers']
    shortchart[i] = frame
    time.sleep(1)
    print("--Done {}--".format(i))
# Out:
# --Done 201935--
# --Done 203081--
# --Done 203507--
# --Done 1626164--
# --Done 1629027--
# --Done 203078--
# --Done 1629029--
# --Done 2544--
# --Done 1628378--
# --Done 203076--
# --Done 201566--
# --Done 203897--
# --Done 203468--
# --Done 1628369--
# --Done 202695--
# --Done 201942--
# --Done 1627742--
# --Done 203999--
# --Done 202699--
# --Done 1627783--
# --Done 1629012--
# --Done 1627741--
# --Done 203933--
# --Done 203915--
# --Done 1628983--
# --Done 203114--
# --Done 202711--
# --Done 203944--
# --Done 203095--
# --Done 101108--
# --Done 203471--
# --Done 202696--
# --Done 203952--
# --Done 1626149--
# --Done 201950--
# --Done 101150--
# --Done 1629630--
# --Done 203954--
# --Done 1627759--
# --Done 202710--
# --Done 1627734--
# --Done 1628984--
# --Done 201568--
# --Done 1628389--
# --Done 1628415--
# --Done 1626179--
# --Done 204001--
# --Done 202689--
# --Done 200768--
# --Done 203501--

# %%
for i,ids in enumerate(Player_ids):
    if i == 0:
        df = shortchart[ids]
        #print(df)
    if i>0:
        df = pd.concat([df,shortchart[ids]])

# %%
df.to_csv('shortchart_top50.csv')

# %%
df.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0  Shot Chart Detail  0021900015             20     201935  James Harden
# 1  Shot Chart Detail  0021900015            117     201935  James Harden
# 2  Shot Chart Detail  0021900015            267     201935  James Harden
# 3  Shot Chart Detail  0021900015            324     201935  James Harden
# 4  Shot Chart Detail  0021900015            350     201935  James Harden
#
#       TEAM_ID        TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612745  Houston Rockets       1                 10                 51
# 1  1610612745  Houston Rockets       1                  4                 43
# 2  1610612745  Houston Rockets       2                  8                 31
# 3  1610612745  Houston Rockets       2                  4                 18
# 4  1610612745  Houston Rockets       2                  2                  6
#
# ...

# %% [markdown]
# ### Season Leaders

# %%
headers = { "Accept": "application/json, text/plain, */*",
"Accept-Encoding": "gzip, deflate, br",
"Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
"Cache-Control": "no-cache",
"Connection": "keep-alive",
"Host": "stats.nba.com",
"Pragma": "no-cache",
"Referer": "https://stats.nba.com/players/traditional/?SeasonType=Regular%20Season&sort=PTS&dir=-1&Season=2019-20",
"Sec-Fetch-Dest": "empty",
"Sec-Fetch-Mode": "cors",
"Sec-Fetch-Site": "same-origin",
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
"x-nba-stats-origin": "stats",
"x-nba-stats-token": "true",
"X-NewRelic-ID": "VQECWF5UChAHUlNTBwgBVw==" }

params = (
    ('College',''),
    ('Conference',''),
    ('Country',''),
    ('DateFrom',''),
    ('DateTo',''),
    ('Division',''),
    ('DraftPick',''),
    ('DraftYear',''),
    ('GameScope',''),
    ('GameSegment',''),
    ('Height',''),
    ('LastNGames','0'),
    ('LeagueID','00'),
    ('Location',''),
    ('MeasureType', 'Base'),
    ('Month','0'),
    ('OpponentTeamID', '0'),
    ('Outcome',''),
    ('PORound', '0'),
    ('PaceAdjust','N'),
    ('PerMode', 'PerGame'),
    ('Period', '0'),
    ('PlayerExperience',''), 
    ('PlayerPosition',''),
    ('PlusMinus', 'N'),
    ('Rank', 'N'),
    ('Season', '2019-20'),
    ('SeasonSegment',''),
    ('SeasonType', 'Regular Season'),
    ('ShotClockRange' ,''),
    ('StarterBench',''),
    ('TeamID', '0'),
    ('TwoWay', '0'),
    ('VsConference',''), 
    ('VsDivision',''),
    ('Weight',''))

response = requests.get('https://stats.nba.com/stats/leaguedashplayerstats', headers=headers, params=params)

jsn = response.json()
frame = pd.DataFrame(jsn['resultSets'][0]['rowSet'])
frame.columns = jsn['resultSets'][0]['headers']
frame.head(10)
# Out:
#    PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP   W   L  W_PCT   MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  TOV  STL  BLK  BLKA   PF  PFD   PTS  PLUS_MINUS  NBA_FANTASY_PTS  DD2  TD3  GP_RANK  W_RANK  L_RANK  W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  CFID            CFPARAMS
# ...
